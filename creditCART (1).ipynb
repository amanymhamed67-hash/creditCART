# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

from sklearn.svm import OneClassSVM

# %%
df=pd.read_csv('/content/creditcard.csv')
df.head()
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111004 entries, 0 to 111003
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    111004 non-null  int64
#  1   V1      111004 non-null  float64
#  2   V2      111004 non-null  float64
#  3   V3      111004 non-null  float64
#  4   V4      111004 non-null  float64
#  5   V5      111004 non-null  float64
#  6   V6      111004 non-null  float64
#  7   V7      111004 non-null  float64
#  8   V8      111004 non-null  float64
#  9   V9      111004 non-null  float64
#  10  V10     111004 non-null  float64
#  11  V11     111004 non-null  float64
#  12  V12     111004 non-null  float64
#  13  V13     111004 non-null  float64
#  14  V14     111004 non-null  float64
#  15  V15     111004 non-null  float64
#  16  V16     111004 non-null  float64
#  17  V17     111004 non-null  float64
#  18  V18     111004 non-null  float64
#  19  V19     111004 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df = df.drop_duplicates()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5098/3528702638.py in <cell line: 0>()
# ----> 1 df = df.drop_duplicates()
#
# NameError: name 'df' is not defined

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Class"].value_counts()
# Out:
# Class
# 0.0    110334
# 1.0       234
# Name: count, dtype: int64

# %%
x = df.drop("Class", axis=1)
y = df["Class"]

# %%
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2, random_state=42)

# %%
model = OneClassSVM(
    kernel='rbf',
    gamma='scale',
    nu=0.05
)

model.fit(x_scaled)
# Out:
# OneClassSVM(nu=0.05)

# %%
y_pred = model.predict(x_scaled)

# %%
y_pred = model.predict(x_scaled)
y_anomaly = np.where(y_pred == -1, 1, 0)

# %%
print(":", sum(y_anomaly)/len(y_anomaly))
# Out:
# : 0.05498111258519591

# %%
y_pred = model.predict(x_scaled)
y_anomaly = np.where(y_pred == -1, 1, 0)

df_result = pd.DataFrame(x)
df_result["anomaly"] = y_anomaly

df_result[df_result["anomaly"] == 1].head(10)
# Out:
#      Time        V1        V2        V3        V4        V5        V6  \
# 7       7 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118
# 18     14 -5.401258 -5.450148  1.186305  1.736239  3.049106 -1.763406
# 51     36 -1.004929 -0.985978 -0.038039  3.710061 -6.631951  5.122103
# 69     46 -1.923213 -0.870482  2.320170  1.988776  0.417091 -0.380014
# 82     52 -3.005237  2.600138  1.483691 -2.418473  0.306326 -0.824575
# 83     53 -1.198968 -1.474100  1.840326 -4.515824  0.327567 -0.174469
# 85     55 -4.575093 -4.429184  3.402585  0.903915  3.002224 -0.491078
# 104    69 -1.766645  2.352984 -0.009955 -0.363736  1.460953 -0.204833
# 132    83 -1.864990  0.910874  1.724863 -1.748371  0.578943 -0.832531
# 134    83 -1.897331  0.955626  0.052543  1.276656 -3.323084  3.229911
#
#            V7        V8        V9  ...       V21       V22       V23  \
# 7    1.120631 -3.807864  0.615375  ...  1.943465 -1.015455  0.057504
# ...

# %%
print(x_train)
print(y_train)
# Out:
# [[ 1.30208466 -1.34238    -0.1581849  ... -1.14769163  0.92381191
#   -0.28113132]
#  [ 0.46543844  0.79742288  0.20092284 ... -0.02720022  0.07733219
#   -0.36499622]
#  [-0.10930354 -0.00756386  0.55538607 ... -0.32684405 -0.14060242
#   -0.34074381]
#  ...
#  [ 1.31396177 -0.93454071 -0.96263051 ...  0.07391784 -0.44662961
#    1.26083754]
#  [-2.45666381 -0.0482959   0.51520335 ...  0.6895626  -0.05353802
#   -0.34174312]
#  [-0.98528236  0.78642916  0.13929885 ... -0.04809984  0.03053719
#   -0.36499622]]
# 103527    0.0
# 69716     0.0
# 47248     0.0
# 9422      0.0
# 38371     0.0
#          ...
# 77123     0.0
# 110703    0.0
# 104104    0.0
# 867       0.0
# 15848     0.0
# Name: Class, Length: 88454, dtype: float64

# %%
y_train_pred_raw = model.predict(x_train)
y_train_pred_anomaly = np.where(y_train_pred_raw == -1, 1, 0)

y_test_pred_raw = model.predict(x_test)
y_test_pred_anomaly = np.where(y_test_pred_raw == -1, 1, 0)

print(f"Train Accuracy: {accuracy_score(y_train, y_train_pred_anomaly)}")
print(f"Test Accuracy: {accuracy_score(y_test, y_test_pred_anomaly)}")
# Out:
# Train Accuracy: 0.9519524272503223
# Test Accuracy: 0.9504386361580899
